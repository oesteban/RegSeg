# %% [markdown]
# <h2>Deformation field generation</h2>

# %%
from scipy.interpolate import griddata
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
import nibabel as nib
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
msk = nib.load('Model1/signal_mask.nii.gz')
img = nib.load('Model1/signal_b0_merged.nii.gz')
datashape = msk.get_shape()
x,y,z = np.mgrid[0:datashape[0],0:datashape[1], 0:datashape[2] ]

# %%
points = np.concatenate( ([ (33,33,33), (33,66,33), (33,43,33),(33,53,33) ],np.random.randint( 0, 101, size=(100,3) ) ))
values = np.zeros( shape=np.shape(points) )
values[0:4]=[ (0, -10, 0), (0, -11, 0), (0, 6, 0), (0, 2, 0) ]

field = griddata(points, values, (x,y,z), method='linear', fill_value=0)
field[:,:,:,1] = gaussian_filter( field[:,:,:,1], sigma=5 )

# %%
extent=[0,datashape[0],0,datashape[1]]
plt.imshow( field[30,:,:,1], extent=extent )
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7e50878>

# %%
nii = nib.Nifti1Image( field, np.identity(4), img.get_header() )
nib.save( nii, 'Model1/deformed2_field.nii.gz' )

# %%
img_data = img.get_data()
grid_points =  np.array( (x,y,z)).T
new_positions = ( grid_points - field ).reshape(-1,3).T
new_img = np.array( [ map_coordinates( img_data[:,:,:,i], new_positions ).reshape( datashape ) for i in range(0, img_data.shape[-1] ) ] )
new_img[new_img<0.0] = 0.0
niiHS = nib.Nifti1Image( new_img.T, img.get_affine(), img.get_header() )
nib.save( niiHS, 'Model1/deformed2_signal.nii.gz' )

# %%
msk_data = msk.get_data()
new_mask = map_coordinates( msk_data, new_positions ).reshape( datashape )
new_mask[new_mask<=0.5] = 0.0
new_mask[new_mask>0.0] = 1.0
niiHS = nib.Nifti1Image( new_mask, msk.get_affine(), msk.get_header() )
nib.save( niiHS, 'Model1/deformed2_mask.nii.gz' )

# %% [markdown]
# <h2>DTI Fitting</h2>

# %%
import nipype.interfaces.base as base        # base pipeline interface (e.g. command line execution)
import nipype.interfaces.io as nio           # Data i/o
import nipype.interfaces.utility as util     # utility
import nipype.algorithms.misc as misc
import nipype.pipeline.engine as pe          # pypeline engine
import nipype.interfaces.fsl as fsl          # fsl
import nipype.interfaces.freesurfer as fs    # freesurfer
import nipype.interfaces.diffusion_toolkit as dtk
import nipype.interfaces.mrtrix as mrtrix   #<---- The important new part!
import nipype.interfaces.camino as camino

fsl.FSLCommand.set_default_output_type('NIFTI_GZ')
# Out:
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/mrtrix/convert.py:28: UserWarning: dipy not installed
#   warnings.warn('dipy not installed')

# %%
base_dir = os.path.abspath( os.path.abspath( 'Model1' ) )
pipeline = pe.Workflow(name="Model_Process", base_dir = base_dir)

fsmask = pe.Node(interface=fs.ApplyMask(), name='MaskRawData' )
fsmask.inputs.in_file = os.path.abspath( os.path.join( 'Model1', 'deformed2_signal.nii.gz' ))
fsmask.inputs.mask_file = os.path.abspath( os.path.join( 'Model1', 'deformed2_mask.nii.gz' ))

datasink = pe.Node(nio.DataSink(base_directory=base_dir,parameterization=False), name='sinker')
datasink.container = 'deformed'

dtifit = pe.Node( interface=fsl.DTIFit(output_type='NIFTI_GZ'), name='TensorFitting' )
dtifit.inputs.bvecs = os.path.abspath( os.path.join( 'Model1', 'signal.bvec' ) )
dtifit.inputs.bvals = os.path.abspath( os.path.join( 'Model1', 'signal.bval' ) )
dtifit.inputs.mask = os.path.abspath( os.path.join( 'Model1', 'deformed_mask.nii.gz' ) )
dtifit.inputs.dwi = os.path.abspath( os.path.join( 'Model1', 'deformed_signal.nii.gz' ) )

# connect nodes
pipeline.connect([
                        (dtifit,datasink, [( 'FA','@FA'), ('MD','@ADC') ] )
                      ])

# %%
pipeline.run()
# Out:
# 121210-22:12:06,576 workflow INFO:
# 	 ['check', 'execution', 'logging']
# 121210-22:12:06,591 workflow INFO:
# 	 Running serially.
# 121210-22:12:06,592 workflow INFO:
# 	 Executing node TensorFitting in dir: /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/Model_Process/TensorFitting
# 121210-22:12:06,670 workflow INFO:
# 	 Running: dtifit -k /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/deformed_signal.nii.gz -o dtifit_ -m /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/deformed_mask.nii.gz -r /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/signal.bvec -b /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/signal.bval
# 121210-22:12:09,918 interface INFO:
# 	 stdout 2012-12-10T22:12:09.918367:0 101 0 101 0 101
# 121210-22:12:10,14 interface INFO:
# 	 stdout 2012-12-10T22:12:10.014695:0 slices processed
# 121210-22:12:10,15 interface INFO:
# 	 stdout 2012-12-10T22:12:10.015446:1 slices processed
# 121210-22:12:10,15 interface INFO:
# 	 stdout 2012-12-10T22:12:10.015446:2 slices processed
# 121210-22:12:10,16 interface INFO:
# 	 stdout 2012-12-10T22:12:10.015446:3 slices processed
# 121210-22:12:10,16 interface INFO:
# 	 stdout 2012-12-10T22:12:10.015446:4 slices processed
# 121210-22:12:10,17 interface INFO:
# 	 stdout 2012-12-10T22:12:10.015446:5 slices processed
# 121210-22:12:10,19 interface INFO:
# 	 stdout 2012-12-10T22:12:10.015446:6 slices processed
# 121210-22:12:10,19 interface INFO:
# 	 stdout 2012-12-10T22:12:10.015446:7 slices processed
# 121210-22:12:10,20 interface INFO:
# 	 stdout 2012-12-10T22:12:10.015446:8 slices processed
# 121210-22:12:10,20 interface INFO:
# 	 stdout 2012-12-10T22:12:10.015446:9 slices processed
# 121210-22:12:10,21 interface INFO:
# 	 stdout 2012-12-10T22:12:10.015446:10 slices processed
# 121210-22:12:10,22 interface INFO:
# 	 stdout 2012-12-10T22:12:10.022065:11 slices processed
# 121210-22:12:10,22 interface INFO:
# 	 stdout 2012-12-10T22:12:10.022065:12 slices processed
# 121210-22:12:10,23 interface INFO:
# 	 stdout 2012-12-10T22:12:10.023248:13 slices processed
# 121210-22:12:10,35 interface INFO:
# 	 stdout 2012-12-10T22:12:10.035776:14 slices processed
# 121210-22:12:10,47 interface INFO:
# 	 stdout 2012-12-10T22:12:10.046961:15 slices processed
# 121210-22:12:10,62 interface INFO:
# 	 stdout 2012-12-10T22:12:10.062619:16 slices processed
# 121210-22:12:10,82 interface INFO:
# 	 stdout 2012-12-10T22:12:10.082815:17 slices processed
# 121210-22:12:10,106 interface INFO:
# 	 stdout 2012-12-10T22:12:10.106427:18 slices processed
# 121210-22:12:10,129 interface INFO:
# 	 stdout 2012-12-10T22:12:10.129331:19 slices processed
# 121210-22:12:10,156 interface INFO:
# 	 stdout 2012-12-10T22:12:10.156418:20 slices processed
# 121210-22:12:10,184 interface INFO:
# 	 stdout 2012-12-10T22:12:10.184380:21 slices processed
# 121210-22:12:10,229 interface INFO:
# 	 stdout 2012-12-10T22:12:10.229125:22 slices processed
# 121210-22:12:10,261 interface INFO:
# 	 stdout 2012-12-10T22:12:10.261265:23 slices processed
# 121210-22:12:10,298 interface INFO:
# 	 stdout 2012-12-10T22:12:10.298191:24 slices processed
# 121210-22:12:10,341 interface INFO:
# 	 stdout 2012-12-10T22:12:10.341895:25 slices processed
# 121210-22:12:10,386 interface INFO:
# 	 stdout 2012-12-10T22:12:10.386667:26 slices processed
# 121210-22:12:10,427 interface INFO:
# 	 stdout 2012-12-10T22:12:10.427898:27 slices processed
# 121210-22:12:10,470 interface INFO:
# 	 stdout 2012-12-10T22:12:10.470456:28 slices processed
# 121210-22:12:10,515 interface INFO:
# 	 stdout 2012-12-10T22:12:10.515189:29 slices processed
# 121210-22:12:10,561 interface INFO:
# 	 stdout 2012-12-10T22:12:10.561320:30 slices processed
# 121210-22:12:10,610 interface INFO:
# 	 stdout 2012-12-10T22:12:10.610053:31 slices processed
# 121210-22:12:10,659 interface INFO:
# 	 stdout 2012-12-10T22:12:10.659350:32 slices processed
# 121210-22:12:10,709 interface INFO:
# 	 stdout 2012-12-10T22:12:10.709775:33 slices processed
# 121210-22:12:10,762 interface INFO:
# 	 stdout 2012-12-10T22:12:10.762705:34 slices processed
# 121210-22:12:10,817 interface INFO:
# 	 stdout 2012-12-10T22:12:10.817477:35 slices processed
# 121210-22:12:10,873 interface INFO:
# 	 stdout 2012-12-10T22:12:10.873115:36 slices processed
# 121210-22:12:10,929 interface INFO:
# 	 stdout 2012-12-10T22:12:10.929610:37 slices processed
# 121210-22:12:10,986 interface INFO:
# 	 stdout 2012-12-10T22:12:10.986663:38 slices processed
# 121210-22:12:11,44 interface INFO:
# 	 stdout 2012-12-10T22:12:11.044833:39 slices processed
# 121210-22:12:11,104 interface INFO:
# 	 stdout 2012-12-10T22:12:11.103931:40 slices processed
# 121210-22:12:11,164 interface INFO:
# 	 stdout 2012-12-10T22:12:11.164242:41 slices processed
# 121210-22:12:11,228 interface INFO:
# 	 stdout 2012-12-10T22:12:11.228689:42 slices processed
# 121210-22:12:11,291 interface INFO:
# 	 stdout 2012-12-10T22:12:11.291657:43 slices processed
# 121210-22:12:11,353 interface INFO:
# 	 stdout 2012-12-10T22:12:11.353742:44 slices processed
# 121210-22:12:11,416 interface INFO:
# 	 stdout 2012-12-10T22:12:11.416850:45 slices processed
# 121210-22:12:11,479 interface INFO:
# 	 stdout 2012-12-10T22:12:11.479822:46 slices processed
# 121210-22:12:11,543 interface INFO:
# 	 stdout 2012-12-10T22:12:11.543627:47 slices processed
# 121210-22:12:11,608 interface INFO:
# 	 stdout 2012-12-10T22:12:11.607902:48 slices processed
# 121210-22:12:11,673 interface INFO:
# 	 stdout 2012-12-10T22:12:11.673250:49 slices processed
# 121210-22:12:11,737 interface INFO:
# 	 stdout 2012-12-10T22:12:11.737452:50 slices processed
# 121210-22:12:11,800 interface INFO:
# 	 stdout 2012-12-10T22:12:11.800840:51 slices processed
# 121210-22:12:11,864 interface INFO:
# 	 stdout 2012-12-10T22:12:11.864388:52 slices processed
# 121210-22:12:11,927 interface INFO:
# 	 stdout 2012-12-10T22:12:11.927501:53 slices processed
# 121210-22:12:11,990 interface INFO:
# 	 stdout 2012-12-10T22:12:11.990644:54 slices processed
# 121210-22:12:12,56 interface INFO:
# 	 stdout 2012-12-10T22:12:12.056018:55 slices processed
# 121210-22:12:12,120 interface INFO:
# 	 stdout 2012-12-10T22:12:12.120160:56 slices processed
# 121210-22:12:12,183 interface INFO:
# 	 stdout 2012-12-10T22:12:12.183696:57 slices processed
# 121210-22:12:12,244 interface INFO:
# 	 stdout 2012-12-10T22:12:12.244797:58 slices processed
# 121210-22:12:12,305 interface INFO:
# 	 stdout 2012-12-10T22:12:12.305553:59 slices processed
# 121210-22:12:12,365 interface INFO:
# 	 stdout 2012-12-10T22:12:12.365729:60 slices processed
# 121210-22:12:12,425 interface INFO:
# 	 stdout 2012-12-10T22:12:12.425066:61 slices processed
# 121210-22:12:12,483 interface INFO:
# 	 stdout 2012-12-10T22:12:12.483675:62 slices processed
# 121210-22:12:12,540 interface INFO:
# 	 stdout 2012-12-10T22:12:12.540859:63 slices processed
# 121210-22:12:12,597 interface INFO:
# 	 stdout 2012-12-10T22:12:12.597474:64 slices processed
# 121210-22:12:12,652 interface INFO:
# 	 stdout 2012-12-10T22:12:12.652233:65 slices processed
# 121210-22:12:12,706 interface INFO:
# 	 stdout 2012-12-10T22:12:12.706328:66 slices processed
# 121210-22:12:12,758 interface INFO:
# 	 stdout 2012-12-10T22:12:12.758863:67 slices processed
# 121210-22:12:12,810 interface INFO:
# 	 stdout 2012-12-10T22:12:12.810066:68 slices processed
# 121210-22:12:12,860 interface INFO:
# 	 stdout 2012-12-10T22:12:12.859927:69 slices processed
# 121210-22:12:12,908 interface INFO:
# 	 stdout 2012-12-10T22:12:12.908141:70 slices processed
# 121210-22:12:12,957 interface INFO:
# 	 stdout 2012-12-10T22:12:12.956906:71 slices processed
# 121210-22:12:13,3 interface INFO:
# 	 stdout 2012-12-10T22:12:13.003319:72 slices processed
# 121210-22:12:13,46 interface INFO:
# 	 stdout 2012-12-10T22:12:13.046505:73 slices processed
# 121210-22:12:13,88 interface INFO:
# 	 stdout 2012-12-10T22:12:13.088054:74 slices processed
# 121210-22:12:13,127 interface INFO:
# 	 stdout 2012-12-10T22:12:13.127821:75 slices processed
# 121210-22:12:13,165 interface INFO:
# 	 stdout 2012-12-10T22:12:13.165416:76 slices processed
# 121210-22:12:13,200 interface INFO:
# 	 stdout 2012-12-10T22:12:13.200840:77 slices processed
# 121210-22:12:13,234 interface INFO:
# 	 stdout 2012-12-10T22:12:13.234551:78 slices processed
# 121210-22:12:13,269 interface INFO:
# 	 stdout 2012-12-10T22:12:13.269555:79 slices processed
# 121210-22:12:13,301 interface INFO:
# 	 stdout 2012-12-10T22:12:13.301315:80 slices processed
# 121210-22:12:13,329 interface INFO:
# 	 stdout 2012-12-10T22:12:13.329270:81 slices processed
# 121210-22:12:13,354 interface INFO:
# 	 stdout 2012-12-10T22:12:13.354355:82 slices processed
# 121210-22:12:13,377 interface INFO:
# 	 stdout 2012-12-10T22:12:13.377111:83 slices processed
# 121210-22:12:13,396 interface INFO:
# 	 stdout 2012-12-10T22:12:13.396186:84 slices processed
# 121210-22:12:13,415 interface INFO:
# 	 stdout 2012-12-10T22:12:13.415851:85 slices processed
# 121210-22:12:13,433 interface INFO:
# 	 stdout 2012-12-10T22:12:13.433097:86 slices processed
# 121210-22:12:13,444 interface INFO:
# 	 stdout 2012-12-10T22:12:13.443940:87 slices processed
# 121210-22:12:13,451 interface INFO:
# 	 stdout 2012-12-10T22:12:13.451847:88 slices processed
# 121210-22:12:13,456 interface INFO:
# 	 stdout 2012-12-10T22:12:13.456561:89 slices processed
# 121210-22:12:13,457 interface INFO:
# 	 stdout 2012-12-10T22:12:13.457681:90 slices processed
# 121210-22:12:13,458 interface INFO:
# 	 stdout 2012-12-10T22:12:13.457681:91 slices processed
# 121210-22:12:13,459 interface INFO:
# 	 stdout 2012-12-10T22:12:13.457681:92 slices processed
# 121210-22:12:13,459 interface INFO:
# 	 stdout 2012-12-10T22:12:13.457681:93 slices processed
# 121210-22:12:13,460 interface INFO:
# 	 stdout 2012-12-10T22:12:13.457681:94 slices processed
# 121210-22:12:13,460 interface INFO:
# 	 stdout 2012-12-10T22:12:13.457681:95 slices processed
# 121210-22:12:13,461 interface INFO:
# 	 stdout 2012-12-10T22:12:13.457681:96 slices processed
# 121210-22:12:13,461 interface INFO:
# 	 stdout 2012-12-10T22:12:13.457681:97 slices processed
# 121210-22:12:13,462 interface INFO:
# 	 stdout 2012-12-10T22:12:13.457681:98 slices processed
# 121210-22:12:13,462 interface INFO:
# 	 stdout 2012-12-10T22:12:13.457681:99 slices processed
# 121210-22:12:13,463 interface INFO:
# 	 stdout 2012-12-10T22:12:13.457681:100 slices processed
# 121210-22:12:15,482 workflow INFO:
# 	 Executing node sinker in dir: /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/Model_Process/sinker

# %% [markdown]
# <h2>Model restoration</h2>

# %%
est_field = nib.load('../../Debug/deformed2_fieldHD.nii.gz').get_data()
est_field = est_field[:,:,:,0,:]
plt.imshow( field[30,:,:,1] - est_field[30,:,:,1] )
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11cb7b48>

# %%
import math
def get_phi( x, y ):
    if x==0 and y==0:
        return 0
    elif x>=0:
        return math.asin( y / math.sqrt( x**2 + y**2 ) )
    else:
        return -math.asin( y / math.sqrt( x**2 + y**2 ) ) + math.pi
        
vphi = np.vectorize( get_phi )

# %%
from tvtk.api import tvtk
import matplotlib.mlab as ml

def plotSlice( sliceId, points1, points2, fa_data, extent ):
    plt.imshow( fa_data[sliceId,:,:], extent=extent, cmap=cm.gray )
    plt.xticks( [] )
    plt.yticks( [] )
    
    cont1 = points1[ points1[:,1] == sliceId ]
    o = (0.5*(fa_data.shape[0]-1),0.5*(fa_data.shape[2]-1))
    phis = vphi( cont1[:,0]-o[0], cont1[:,2]-o[1])
    res = np.take( cont1, np.argsort(phis), axis=0 )
    plt.plot( res[:,0], res[:,2], linewidth=3 )
    
    if points2==None:
        return
    
    cont2 = points2[ abs(points2[:,1] - sliceId)<0.5 ]
    phis2 = vphi( cont2[:,0]-o[0], cont2[:,2]-o[1])
    res2 = np.take( cont2, np.argsort(phis2), axis=0 )
    plt.plot( res2[:,0], res2[:,2], linewidth=3, color='r' )

# %%
fa = nib.load('Model1/deformed2_FA.nii.gz')
fa_data = fa.get_data()
fa_data = np.swapaxes( fa_data, 0, 1 )
fa_data = np.swapaxes( fa_data, 1, 2 )
extent=[0,fa_data.shape[0]-1,fa_data.shape[1]-1,0]

mesh = tvtk.PolyDataReader( file_name= 'Model1/wm_prior.vtk' )
mesh.output.update()
points1 = np.array( mesh.output.points )
mesh2 = tvtk.PolyDataReader( file_name= '../../Debug/deformed2-wm.vtk' )
mesh2.output.update()
points2 = np.array(mesh2.output.points)

# %%
for i,sl in enumerate([ 25, 35, 45, 55, 65 ]):
    plt.figure(figsize=(15,15) )
    plotSlice( sl, points1, points2, fa_data, extent )
    plt.savefig('fig_contours_%02d.eps' % i, dpi=300, figsize=(15,15), bbox_inches='tight', pad_inches=0 )

# %%
fa = nib.load('Model1/dtifit__FA.nii.gz')
fa_data = fa.get_data()
fa_data = np.swapaxes( fa_data, 0, 1 )
fa_data = np.swapaxes( fa_data, 1, 2 )

for i,sl in enumerate([ 25, 35, 45, 55, 65 ]):
    plt.figure(figsize=(15,15) )
    plotSlice( sl, points1, None, fa_data, extent )
    plt.savefig('fig_modelFA_%02d.eps' % i, dpi=300, figsize=(15,15), bbox_inches='tight', pad_inches=0 )

# %%
grid_points =  np.array( (x,y,z)).T
new_positions = ( grid_points + est_field ).reshape(-1,3).T
new_img = map_coordinates( fa_data, new_positions ).reshape( np.shape(fa_data) )
new_img[new_img<0.0] = 0.0
niiHS = nib.Nifti1Image( new_img.T, fa.get_affine(), fa.get_header() )
nib.save( niiHS, 'Model1/restored_FA.nii.gz' )

# %%
mesh.output.update()
points = np.array( mesh.output.points )
contour = points[ points[:,1] == sliceId ]


#zb = np.array( cont1[:,1] )
#xi = np.linspace(0, datashape[0]-1 )
#yi = np.linspace(0, datashape[1]-1 )
#zi = ml.griddata( cont1[:,0],cont1[:,2], zb, xi, yi)
#plt.contour(xi, yi, zi, levels=[sliceId], linewidths=3 )
#zb2 = np.array( points2[:,1])
#zi2 = ml.griddata( points2[:,0],points2[:,2], zb2, xi, yi)
#plt.contour(xi, yi, zi2, levels=[sliceId], colors='r', linewidths=3 )

#plt.plot( contour2[:,0], contour2[:,2], 'o', color='r', markersize=2 )
# Out:
# [ 63.  30.  27.]
