# %% [markdown]
# <h2>Deformation field generation</h2>

# %%
from scipy.interpolate import griddata
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
import nibabel as nib
import numpy as np
import os

# %%
msk = nib.load('Model1/signal_mask.nii.gz')
img = nib.load('Model1/signal_b0_merged.nii.gz')
datashape = msk.get_shape()
x,y,z = np.mgrid[0:datashape[0],0:datashape[1], 0:datashape[2] ]

# %%
points = np.concatenate( ([ (33,33,33), (33,66,33), (33,43,33),(33,53,33) ],np.random.randint( 0, 101, size=(100,3) ) ))
values = np.zeros( shape=np.shape(points) )
values[0:4]=[ (0, -10, 0), (0, -11, 0), (0, 6, 0), (0, 2, 0) ]

field = griddata(points, values, (x,y,z), method='linear', fill_value=0)
field[:,:,:,1] = gaussian_filter( field[:,:,:,1], sigma=5 )

# %%
extent=[0,datashape[0],0,datashape[1]]
plt.imshow( field[30,:,:,1], extent=extent )

# %%
img_data = img.get_data()
grid_points =  np.array( (x,y,z)).T
new_positions = ( grid_points - field ).reshape(-1,3).T
new_img = np.array( [ map_coordinates( img_data[:,:,:,i], new_positions ).reshape( datashape ) for i in range(0, img_data.shape[-1] ) ] )
new_img[new_img<0.0] = 0.0
niiHS = nib.Nifti1Image( new_img.T, img.get_affine(), img.get_header() )
nib.save( niiHS, 'Model1/deformed_signal.nii.gz' )

# %%
msk_data = msk.get_data()
new_mask = map_coordinates( msk_data, new_positions ).reshape( datashape )
new_mask[new_mask<=0.5] = 0.0
new_mask[new_mask>0.0] = 1.0
niiHS = nib.Nifti1Image( new_mask, msk.get_affine(), msk.get_header() )
nib.save( niiHS, 'Model1/deformed_mask.nii.gz' )

# %% [markdown]
# <h2>DTI Fitting</h2>

# %%
import nipype.interfaces.base as base        # base pipeline interface (e.g. command line execution)
import nipype.interfaces.io as nio           # Data i/o
import nipype.interfaces.utility as util     # utility
import nipype.algorithms.misc as misc
import nipype.pipeline.engine as pe          # pypeline engine
import nipype.interfaces.fsl as fsl          # fsl
import nipype.interfaces.freesurfer as fs    # freesurfer
import nipype.interfaces.diffusion_toolkit as dtk
import nipype.interfaces.mrtrix as mrtrix   #<---- The important new part!
import nipype.interfaces.camino as camino

fsl.FSLCommand.set_default_output_type('NIFTI_GZ')
# Out:
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/mrtrix/convert.py:28: UserWarning: dipy not installed
#   warnings.warn('dipy not installed')

# %%
base_dir = os.path.abspath( os.path.abspath( 'Model1' ) )
pipeline = pe.Workflow(name="Model_Process", base_dir = base_dir)

fsmask = pe.Node(interface=fs.ApplyMask(), name='MaskRawData' )
fsmask.inputs.in_file = os.path.abspath( os.path.join( 'Model1', 'deformed_signal.nii.gz' ))
fsmask.inputs.mask_file = os.path.abspath( os.path.join( 'Model1', 'deformed_mask.nii.gz' ))

datasink = pe.Node(nio.DataSink(base_directory=base_dir,parameterization=False), name='sinker')
datasink.container = 'deformed'

dtifit = pe.Node( interface=fsl.DTIFit(output_type='NIFTI_GZ'), name='TensorFitting' )
dtifit.inputs.bvecs = os.path.abspath( os.path.join( 'Model1', 'signal.bvec' ) )
dtifit.inputs.bvals = os.path.abspath( os.path.join( 'Model1', 'signal.bval' ) )
dtifit.inputs.mask = os.path.abspath( os.path.join( 'Model1', 'deformed_mask.nii.gz' ) )
dtifit.inputs.dwi = os.path.abspath( os.path.join( 'Model1', 'deformed_signal.nii.gz' ) )

# connect nodes
pipeline.connect([
                        (dtifit,datasink, [( 'FA','@FA'), ('MD','@ADC') ] )
                      ])

# %%
pipeline.run()
# Out:
# 121204-11:01:59,590 workflow INFO:
# 	 ['check', 'execution', 'logging']
# 121204-11:01:59,606 workflow INFO:
# 	 Running serially.
# 121204-11:01:59,608 workflow INFO:
# 	 Executing node TensorFitting in dir: /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/Model_Process/TensorFitting
# 121204-11:01:59,626 workflow INFO:
# 	 Running: dtifit -k /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/deformed_signal.nii.gz -o dtifit_ -m /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/deformed_mask.nii.gz -r /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/signal.bvec -b /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/signal.bval
# 121204-11:02:01,611 interface INFO:
# 	 stdout 2012-12-04T11:02:01.611288:0 101 0 101 0 101
# 121204-11:02:01,663 interface INFO:
# 	 stdout 2012-12-04T11:02:01.663311:0 slices processed
# 121204-11:02:01,664 interface INFO:
# 	 stdout 2012-12-04T11:02:01.663311:1 slices processed
# 121204-11:02:01,664 interface INFO:
# 	 stdout 2012-12-04T11:02:01.664460:2 slices processed
# 121204-11:02:01,664 interface INFO:
# 	 stdout 2012-12-04T11:02:01.664460:3 slices processed
# 121204-11:02:01,665 interface INFO:
# 	 stdout 2012-12-04T11:02:01.664460:4 slices processed
# 121204-11:02:01,666 interface INFO:
# 	 stdout 2012-12-04T11:02:01.664460:5 slices processed
# 121204-11:02:01,666 interface INFO:
# 	 stdout 2012-12-04T11:02:01.664460:6 slices processed
# 121204-11:02:01,667 interface INFO:
# 	 stdout 2012-12-04T11:02:01.664460:7 slices processed
# 121204-11:02:01,667 interface INFO:
# 	 stdout 2012-12-04T11:02:01.664460:8 slices processed
# 121204-11:02:01,669 interface INFO:
# 	 stdout 2012-12-04T11:02:01.664460:9 slices processed
# 121204-11:02:01,671 interface INFO:
# 	 stdout 2012-12-04T11:02:01.664460:10 slices processed
# 121204-11:02:01,672 interface INFO:
# 	 stdout 2012-12-04T11:02:01.664460:11 slices processed
# 121204-11:02:01,673 interface INFO:
# 	 stdout 2012-12-04T11:02:01.664460:12 slices processed
# 121204-11:02:01,674 interface INFO:
# 	 stdout 2012-12-04T11:02:01.674758:13 slices processed
# 121204-11:02:01,676 interface INFO:
# 	 stdout 2012-12-04T11:02:01.676760:14 slices processed
# 121204-11:02:01,688 interface INFO:
# 	 stdout 2012-12-04T11:02:01.688067:15 slices processed
# 121204-11:02:01,703 interface INFO:
# 	 stdout 2012-12-04T11:02:01.703793:16 slices processed
# 121204-11:02:01,721 interface INFO:
# 	 stdout 2012-12-04T11:02:01.721008:17 slices processed
# 121204-11:02:01,741 interface INFO:
# 	 stdout 2012-12-04T11:02:01.741823:18 slices processed
# 121204-11:02:01,766 interface INFO:
# 	 stdout 2012-12-04T11:02:01.766554:19 slices processed
# 121204-11:02:01,795 interface INFO:
# 	 stdout 2012-12-04T11:02:01.795771:20 slices processed
# 121204-11:02:01,825 interface INFO:
# 	 stdout 2012-12-04T11:02:01.824985:21 slices processed
# 121204-11:02:01,856 interface INFO:
# 	 stdout 2012-12-04T11:02:01.856316:22 slices processed
# 121204-11:02:01,888 interface INFO:
# 	 stdout 2012-12-04T11:02:01.888836:23 slices processed
# 121204-11:02:01,923 interface INFO:
# 	 stdout 2012-12-04T11:02:01.923148:24 slices processed
# 121204-11:02:01,962 interface INFO:
# 	 stdout 2012-12-04T11:02:01.962319:25 slices processed
# 121204-11:02:02,0 interface INFO:
# 	 stdout 2012-12-04T11:02:02.000607:26 slices processed
# 121204-11:02:02,41 interface INFO:
# 	 stdout 2012-12-04T11:02:02.041637:27 slices processed
# 121204-11:02:02,84 interface INFO:
# 	 stdout 2012-12-04T11:02:02.084030:28 slices processed
# 121204-11:02:02,127 interface INFO:
# 	 stdout 2012-12-04T11:02:02.127712:29 slices processed
# 121204-11:02:02,173 interface INFO:
# 	 stdout 2012-12-04T11:02:02.173742:30 slices processed
# 121204-11:02:02,221 interface INFO:
# 	 stdout 2012-12-04T11:02:02.220955:31 slices processed
# 121204-11:02:02,271 interface INFO:
# 	 stdout 2012-12-04T11:02:02.270986:32 slices processed
# 121204-11:02:02,334 interface INFO:
# 	 stdout 2012-12-04T11:02:02.334318:33 slices processed
# 121204-11:02:02,387 interface INFO:
# 	 stdout 2012-12-04T11:02:02.386988:34 slices processed
# 121204-11:02:02,441 interface INFO:
# 	 stdout 2012-12-04T11:02:02.441627:35 slices processed
# 121204-11:02:02,497 interface INFO:
# 	 stdout 2012-12-04T11:02:02.497190:36 slices processed
# 121204-11:02:02,554 interface INFO:
# 	 stdout 2012-12-04T11:02:02.554504:37 slices processed
# 121204-11:02:02,619 interface INFO:
# 	 stdout 2012-12-04T11:02:02.619004:38 slices processed
# 121204-11:02:02,680 interface INFO:
# 	 stdout 2012-12-04T11:02:02.680756:39 slices processed
# 121204-11:02:02,741 interface INFO:
# 	 stdout 2012-12-04T11:02:02.741261:40 slices processed
# 121204-11:02:02,800 interface INFO:
# 	 stdout 2012-12-04T11:02:02.800599:41 slices processed
# 121204-11:02:02,860 interface INFO:
# 	 stdout 2012-12-04T11:02:02.860870:42 slices processed
# 121204-11:02:02,922 interface INFO:
# 	 stdout 2012-12-04T11:02:02.921912:43 slices processed
# 121204-11:02:02,984 interface INFO:
# 	 stdout 2012-12-04T11:02:02.984639:44 slices processed
# 121204-11:02:03,49 interface INFO:
# 	 stdout 2012-12-04T11:02:03.049324:45 slices processed
# 121204-11:02:03,112 interface INFO:
# 	 stdout 2012-12-04T11:02:03.112417:46 slices processed
# 121204-11:02:03,188 interface INFO:
# 	 stdout 2012-12-04T11:02:03.188771:47 slices processed
# 121204-11:02:03,261 interface INFO:
# 	 stdout 2012-12-04T11:02:03.261251:48 slices processed
# 121204-11:02:03,324 interface INFO:
# 	 stdout 2012-12-04T11:02:03.324531:49 slices processed
# 121204-11:02:03,387 interface INFO:
# 	 stdout 2012-12-04T11:02:03.387491:50 slices processed
# 121204-11:02:03,450 interface INFO:
# 	 stdout 2012-12-04T11:02:03.450222:51 slices processed
# 121204-11:02:03,513 interface INFO:
# 	 stdout 2012-12-04T11:02:03.513410:52 slices processed
# 121204-11:02:03,588 interface INFO:
# 	 stdout 2012-12-04T11:02:03.588321:53 slices processed
# 121204-11:02:03,669 interface INFO:
# 	 stdout 2012-12-04T11:02:03.669311:54 slices processed
# 121204-11:02:03,732 interface INFO:
# 	 stdout 2012-12-04T11:02:03.732498:55 slices processed
# 121204-11:02:03,796 interface INFO:
# 	 stdout 2012-12-04T11:02:03.796344:56 slices processed
# 121204-11:02:03,859 interface INFO:
# 	 stdout 2012-12-04T11:02:03.859645:57 slices processed
# 121204-11:02:03,921 interface INFO:
# 	 stdout 2012-12-04T11:02:03.921343:58 slices processed
# 121204-11:02:03,983 interface INFO:
# 	 stdout 2012-12-04T11:02:03.983105:59 slices processed
# 121204-11:02:04,46 interface INFO:
# 	 stdout 2012-12-04T11:02:04.045938:60 slices processed
# 121204-11:02:04,107 interface INFO:
# 	 stdout 2012-12-04T11:02:04.107307:61 slices processed
# 121204-11:02:04,171 interface INFO:
# 	 stdout 2012-12-04T11:02:04.170985:62 slices processed
# 121204-11:02:04,231 interface INFO:
# 	 stdout 2012-12-04T11:02:04.231195:63 slices processed
# 121204-11:02:04,288 interface INFO:
# 	 stdout 2012-12-04T11:02:04.288057:64 slices processed
# 121204-11:02:04,343 interface INFO:
# 	 stdout 2012-12-04T11:02:04.343331:65 slices processed
# 121204-11:02:04,397 interface INFO:
# 	 stdout 2012-12-04T11:02:04.397669:66 slices processed
# 121204-11:02:04,451 interface INFO:
# 	 stdout 2012-12-04T11:02:04.451278:67 slices processed
# 121204-11:02:04,503 interface INFO:
# 	 stdout 2012-12-04T11:02:04.503309:68 slices processed
# 121204-11:02:04,555 interface INFO:
# 	 stdout 2012-12-04T11:02:04.555696:69 slices processed
# 121204-11:02:04,605 interface INFO:
# 	 stdout 2012-12-04T11:02:04.605391:70 slices processed
# 121204-11:02:04,653 interface INFO:
# 	 stdout 2012-12-04T11:02:04.653319:71 slices processed
# 121204-11:02:04,701 interface INFO:
# 	 stdout 2012-12-04T11:02:04.701657:72 slices processed
# 121204-11:02:04,747 interface INFO:
# 	 stdout 2012-12-04T11:02:04.747140:73 slices processed
# 121204-11:02:04,790 interface INFO:
# 	 stdout 2012-12-04T11:02:04.789998:74 slices processed
# 121204-11:02:04,831 interface INFO:
# 	 stdout 2012-12-04T11:02:04.831515:75 slices processed
# 121204-11:02:04,870 interface INFO:
# 	 stdout 2012-12-04T11:02:04.870865:76 slices processed
# 121204-11:02:04,909 interface INFO:
# 	 stdout 2012-12-04T11:02:04.909429:77 slices processed
# 121204-11:02:04,944 interface INFO:
# 	 stdout 2012-12-04T11:02:04.944576:78 slices processed
# 121204-11:02:04,977 interface INFO:
# 	 stdout 2012-12-04T11:02:04.977455:79 slices processed
# 121204-11:02:05,7 interface INFO:
# 	 stdout 2012-12-04T11:02:05.007666:80 slices processed
# 121204-11:02:05,37 interface INFO:
# 	 stdout 2012-12-04T11:02:05.037411:81 slices processed
# 121204-11:02:05,64 interface INFO:
# 	 stdout 2012-12-04T11:02:05.064501:82 slices processed
# 121204-11:02:05,86 interface INFO:
# 	 stdout 2012-12-04T11:02:05.086810:83 slices processed
# 121204-11:02:05,106 interface INFO:
# 	 stdout 2012-12-04T11:02:05.106032:84 slices processed
# 121204-11:02:05,123 interface INFO:
# 	 stdout 2012-12-04T11:02:05.122922:85 slices processed
# 121204-11:02:05,137 interface INFO:
# 	 stdout 2012-12-04T11:02:05.137011:86 slices processed
# 121204-11:02:05,148 interface INFO:
# 	 stdout 2012-12-04T11:02:05.148509:87 slices processed
# 121204-11:02:05,157 interface INFO:
# 	 stdout 2012-12-04T11:02:05.157064:88 slices processed
# 121204-11:02:05,162 interface INFO:
# 	 stdout 2012-12-04T11:02:05.162269:89 slices processed
# 121204-11:02:05,163 interface INFO:
# 	 stdout 2012-12-04T11:02:05.163189:90 slices processed
# 121204-11:02:05,164 interface INFO:
# 	 stdout 2012-12-04T11:02:05.163189:91 slices processed
# 121204-11:02:05,164 interface INFO:
# 	 stdout 2012-12-04T11:02:05.163189:92 slices processed
# 121204-11:02:05,165 interface INFO:
# 	 stdout 2012-12-04T11:02:05.163189:93 slices processed
# 121204-11:02:05,166 interface INFO:
# 	 stdout 2012-12-04T11:02:05.163189:94 slices processed
# 121204-11:02:05,166 interface INFO:
# 	 stdout 2012-12-04T11:02:05.163189:95 slices processed
# 121204-11:02:05,167 interface INFO:
# 	 stdout 2012-12-04T11:02:05.163189:96 slices processed
# 121204-11:02:05,168 interface INFO:
# 	 stdout 2012-12-04T11:02:05.163189:97 slices processed
# 121204-11:02:05,168 interface INFO:
# 	 stdout 2012-12-04T11:02:05.163189:98 slices processed
# 121204-11:02:05,169 interface INFO:
# 	 stdout 2012-12-04T11:02:05.163189:99 slices processed
# 121204-11:02:05,170 interface INFO:
# 	 stdout 2012-12-04T11:02:05.170124:100 slices processed
# 121204-11:02:07,268 workflow INFO:
# 	 Executing node sinker in dir: /media/Datos/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/Model_Process/sinker
