# %% [markdown]
# <h1>Distortion of dMRI using the inverse fieldmap technique</h1>
# Procedure:
# <ol>
#     <li>Create map with range [0..2&pi;]</li>
#     <li>Phase unwrap (prelude)</li>
#     <li>Convert to rad/sec</li>
#     <li>Subtract median</li>
#     <li>Create VSM (voxel shift map)</li>
#     <li>(Optional) Smooth VSM</li>
#     <li>(Optional) demean VSM</li>
#     <li>Distort image (apply forward map in fugue)</li>
# </ol>

# %%
import nibabel as nib
import numpy as np
import os.path as op
import os

# %%
root_dir='/home/oesteban/workspace/ACWE-Reg/'
data_dir= op.join( root_dir, 'Data' )
mname = 'DigitalPhantomISBI'
model_dir = op.join( data_dir, mname )
working_dir= op.join( root_dir, 'temp', mname )

if not op.exists( working_dir ):
    os.makedirs( working_dir )

# %%
maskfile = op.join( model_dir, 'signal_mask.nii.gz' )

msk = nib.load( maskfile )
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-1229a68ec184> in <module>()
#       1 maskfile = op.join( model_dir, 'signal_mask.nii.gz' )
#       2
# ----> 3 msk = nib.load( maskfile )
#
# /usr/local/lib/python2.7/dist-packages/nibabel/loadsave.pyc in load(filename)
#      52         else:
#      53             klass =  spm2.Spm2AnalyzeImage
# ---> 54     return klass.from_filename(filename)
#      55
#      56
#
# /usr/local/lib/python2.7/dist-packages/nibabel/spatialimages.pyc in from_filename(klass, filename)
#     409     def from_filename(klass, filename):
#     410         file_map = klass.filespec_to_file_map(filename)
# --> 411         return klass.from_file_map(file_map)
#     412
#     413     @classmethod
#
# /usr/local/lib/python2.7/dist-packages/nibabel/analyze.pyc in from_file_map(klass, file_map)
#     867         '''
#     868         hdr_fh, img_fh = klass._get_fileholders(file_map)
# --> 869         hdrf = hdr_fh.get_prepare_fileobj(mode='rb')
#     870         header = klass.header_class.from_fileobj(hdrf)
#     871         if hdr_fh.fileobj is None: # was filename
#
# /usr/local/lib/python2.7/dist-packages/nibabel/fileholders.pyc in get_prepare_fileobj(self, *args, **kwargs)
#      67             obj.seek(self.pos)
#      68         elif self.filename is not None:
# ---> 69             obj = allopen(self.filename, *args, **kwargs)
#      70             if self.pos != 0:
#      71                 obj.seek(self.pos)
#
# /usr/local/lib/python2.7/dist-packages/nibabel/volumeutils.pyc in allopen(fname, *args, **kwargs)
#    1282     else:
#    1283         opener = open
# -> 1284     return opener(fname, *args, **kwargs)
#    1285
#    1286
#
# /usr/lib/python2.7/gzip.pyc in open(filename, mode, compresslevel)
#      29
#      30     """
# ---> 31     return GzipFile(filename, mode, compresslevel)
#      32
#      33 class GzipFile(io.BufferedIOBase):
#
# /usr/lib/python2.7/gzip.pyc in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#      89             mode += 'b'
#      90         if fileobj is None:
# ---> 91             fileobj = self.myfileobj = __builtin__.open(filename, mode or 'rb')
#      92         if filename is None:
#      93             # Issue #13781: os.fdopen() creates a fileobj with a bogus name
#
# IOError: [Errno 2] No such file or directory: '/home/oesteban/workspace/ACWE-Reg/Data/DigitalPhantomISBI/signal_mask.nii.gz'

# %% [markdown]
# <h2>Deformation field generation</h2>

# %%
from scipy.interpolate import griddata
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
import nibabel as nib
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
msk = nib.load('Model1/signal_mask.nii.gz')
img = nib.load('Model1/signal_b0_merged.nii.gz')
datashape = msk.get_shape()
x,y,z = np.mgrid[0:datashape[0],0:datashape[1], 0:datashape[2] ]

# %%
points = np.concatenate( ([ (33,33,33), (33,66,33), (33,43,33),(33,53,33) ],np.random.randint( 0, 101, size=(100,3) ) ))
values = np.zeros( shape=np.shape(points) )
values[0:4]=[ (0, -10, 0), (0, -11, 0), (0, 6, 0), (0, 2, 0) ]

field = griddata(points, values, (x,y,z), method='linear', fill_value=0)
field[:,:,:,1] = gaussian_filter( field[:,:,:,1], sigma=5 )

# %%
extent=[0,datashape[0],0,datashape[1]]
plt.imshow( field[30,:,:,1], extent=extent )
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x4191710>

# %%
nii = nib.Nifti1Image( field, np.identity(4), img.get_header() )
nib.save( nii, 'Model1/deformed2_field.nii.gz' )

# %%
field = nib.load('Model1/deformed2_field.nii.gz').get_data()

# %%
img_data = img.get_data()
grid_points =  np.array( (x,y,z)).T
new_positions = ( grid_points - field ).reshape(-1,3).T
new_img = np.array( [ map_coordinates( img_data[:,:,:,i], new_positions ).reshape( datashape ) for i in range(0, img_data.shape[-1] ) ] )
new_img[new_img<0.0] = 0.0
niiHS = nib.Nifti1Image( new_img.T, img.get_affine(), img.get_header() )
nib.save( niiHS, 'Model1/deformed2_signal.nii.gz' )

# %%
msk_data = msk.get_data()
new_mask = map_coordinates( msk_data, new_positions ).reshape( datashape )
new_mask[new_mask<=0.5] = 0.0
new_mask[new_mask>0.0] = 1.0
niiHS = nib.Nifti1Image( new_mask, msk.get_affine(), msk.get_header() )
nib.save( niiHS, 'Model1/deformed2_mask.nii.gz' )

# %% [markdown]
# <h2>DTI Fitting</h2>

# %%
import nipype.interfaces.base as base        # base pipeline interface (e.g. command line execution)
import nipype.interfaces.io as nio           # Data i/o
import nipype.interfaces.utility as util     # utility
import nipype.algorithms.misc as misc
import nipype.pipeline.engine as pe          # pypeline engine
import nipype.interfaces.fsl as fsl          # fsl
import nipype.interfaces.freesurfer as fs    # freesurfer
import nipype.interfaces.diffusion_toolkit as dtk
import nipype.interfaces.mrtrix as mrtrix   #<---- The important new part!
import nipype.interfaces.camino as camino

fsl.FSLCommand.set_default_output_type('NIFTI_GZ')
# Out:
# /usr/local/lib/python2.7/dist-packages/nipype/interfaces/mrtrix/convert.py:28: UserWarning: dipy not installed
#   warnings.warn('dipy not installed')

# %%
base_dir = os.path.abspath( os.path.abspath( 'Model1' ) )
pipeline = pe.Workflow(name="Model_Process", base_dir = base_dir)

fsmask = pe.Node(interface=fs.ApplyMask(), name='MaskRawData' )
fsmask.inputs.in_file = os.path.abspath( os.path.join( 'Model1', 'deformed2_signal.nii.gz' ))
fsmask.inputs.mask_file = os.path.abspath( os.path.join( 'Model1', 'deformed2_mask.nii.gz' ))

datasink = pe.Node(nio.DataSink(base_directory=base_dir,parameterization=False), name='sinker')
datasink.container = 'deformed'

dtifit = pe.Node( interface=fsl.DTIFit(output_type='NIFTI_GZ'), name='TensorFitting' )
dtifit.inputs.bvecs = os.path.abspath( os.path.join( 'Model1', 'signal.bvec' ) )
dtifit.inputs.bvals = os.path.abspath( os.path.join( 'Model1', 'signal.bval' ) )
dtifit.inputs.mask = os.path.abspath( os.path.join( 'Model1', 'deformed_mask.nii.gz' ) )
dtifit.inputs.dwi = os.path.abspath( os.path.join( 'Model1', 'deformed_signal.nii.gz' ) )

# connect nodes
pipeline.connect([
                        (dtifit,datasink, [( 'FA','@FA'), ('MD','@ADC') ] )
                      ])

# %%
pipeline.run()
# Out:
# 130110-14:05:05,111 workflow INFO:
# 	 ['check', 'execution', 'logging']
# 130110-14:05:05,116 workflow INFO:
# 	 Running serially.
# 130110-14:05:05,117 workflow INFO:
# 	 Executing node TensorFitting in dir: /home/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/Model_Process/TensorFitting
# 130110-14:05:05,119 workflow INFO:
# 	 Running: dtifit -k /home/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/deformed_signal.nii.gz -o dtifit_ -m /home/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/deformed_mask.nii.gz -r /home/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/signal.bvec -b /home/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/signal.bval
# 130110-14:05:05,140 interface INFO:
# 	 stdout 2013-01-10T14:05:05.140063:4.1.9
# 130110-14:05:06,622 interface INFO:
# 	 stdout 2013-01-10T14:05:06.622841:0 101 0 101 0 101
# 130110-14:05:06,650 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650003:0 slices processed
# 130110-14:05:06,650 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650003:1 slices processed
# 130110-14:05:06,650 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650744:2 slices processed
# 130110-14:05:06,651 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650744:3 slices processed
# 130110-14:05:06,651 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650744:4 slices processed
# 130110-14:05:06,651 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650744:5 slices processed
# 130110-14:05:06,651 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650744:6 slices processed
# 130110-14:05:06,652 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650744:7 slices processed
# 130110-14:05:06,652 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650744:8 slices processed
# 130110-14:05:06,652 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650744:9 slices processed
# 130110-14:05:06,652 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650744:10 slices processed
# 130110-14:05:06,653 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650744:11 slices processed
# 130110-14:05:06,653 interface INFO:
# 	 stdout 2013-01-10T14:05:06.650744:12 slices processed
# 130110-14:05:06,655 interface INFO:
# 	 stdout 2013-01-10T14:05:06.655583:13 slices processed
# 130110-14:05:06,661 interface INFO:
# 	 stdout 2013-01-10T14:05:06.661186:14 slices processed
# 130110-14:05:06,668 interface INFO:
# 	 stdout 2013-01-10T14:05:06.668434:15 slices processed
# 130110-14:05:06,677 interface INFO:
# 	 stdout 2013-01-10T14:05:06.677342:16 slices processed
# 130110-14:05:06,688 interface INFO:
# 	 stdout 2013-01-10T14:05:06.688109:17 slices processed
# 130110-14:05:06,701 interface INFO:
# 	 stdout 2013-01-10T14:05:06.701729:18 slices processed
# 130110-14:05:06,716 interface INFO:
# 	 stdout 2013-01-10T14:05:06.716300:19 slices processed
# 130110-14:05:06,733 interface INFO:
# 	 stdout 2013-01-10T14:05:06.733004:20 slices processed
# 130110-14:05:06,752 interface INFO:
# 	 stdout 2013-01-10T14:05:06.752252:21 slices processed
# 130110-14:05:06,773 interface INFO:
# 	 stdout 2013-01-10T14:05:06.773239:22 slices processed
# 130110-14:05:06,794 interface INFO:
# 	 stdout 2013-01-10T14:05:06.794841:23 slices processed
# 130110-14:05:06,818 interface INFO:
# 	 stdout 2013-01-10T14:05:06.818290:24 slices processed
# 130110-14:05:06,843 interface INFO:
# 	 stdout 2013-01-10T14:05:06.843019:25 slices processed
# 130110-14:05:06,868 interface INFO:
# 	 stdout 2013-01-10T14:05:06.868438:26 slices processed
# 130110-14:05:06,896 interface INFO:
# 	 stdout 2013-01-10T14:05:06.895976:27 slices processed
# 130110-14:05:06,924 interface INFO:
# 	 stdout 2013-01-10T14:05:06.924710:28 slices processed
# 130110-14:05:06,954 interface INFO:
# 	 stdout 2013-01-10T14:05:06.954884:29 slices processed
# 130110-14:05:06,986 interface INFO:
# 	 stdout 2013-01-10T14:05:06.986407:30 slices processed
# 130110-14:05:07,18 interface INFO:
# 	 stdout 2013-01-10T14:05:07.018660:31 slices processed
# 130110-14:05:07,51 interface INFO:
# 	 stdout 2013-01-10T14:05:07.051553:32 slices processed
# 130110-14:05:07,85 interface INFO:
# 	 stdout 2013-01-10T14:05:07.085852:33 slices processed
# 130110-14:05:07,120 interface INFO:
# 	 stdout 2013-01-10T14:05:07.120887:34 slices processed
# 130110-14:05:07,156 interface INFO:
# 	 stdout 2013-01-10T14:05:07.156928:35 slices processed
# 130110-14:05:07,193 interface INFO:
# 	 stdout 2013-01-10T14:05:07.193750:36 slices processed
# 130110-14:05:07,231 interface INFO:
# 	 stdout 2013-01-10T14:05:07.231565:37 slices processed
# 130110-14:05:07,270 interface INFO:
# 	 stdout 2013-01-10T14:05:07.270345:38 slices processed
# 130110-14:05:07,310 interface INFO:
# 	 stdout 2013-01-10T14:05:07.310109:39 slices processed
# 130110-14:05:07,350 interface INFO:
# 	 stdout 2013-01-10T14:05:07.350262:40 slices processed
# 130110-14:05:07,390 interface INFO:
# 	 stdout 2013-01-10T14:05:07.390532:41 slices processed
# 130110-14:05:07,431 interface INFO:
# 	 stdout 2013-01-10T14:05:07.431830:42 slices processed
# 130110-14:05:07,473 interface INFO:
# 	 stdout 2013-01-10T14:05:07.473741:43 slices processed
# 130110-14:05:07,515 interface INFO:
# 	 stdout 2013-01-10T14:05:07.515825:44 slices processed
# 130110-14:05:07,558 interface INFO:
# 	 stdout 2013-01-10T14:05:07.558287:45 slices processed
# 130110-14:05:07,601 interface INFO:
# 	 stdout 2013-01-10T14:05:07.601258:46 slices processed
# 130110-14:05:07,644 interface INFO:
# 	 stdout 2013-01-10T14:05:07.644335:47 slices processed
# 130110-14:05:07,687 interface INFO:
# 	 stdout 2013-01-10T14:05:07.687378:48 slices processed
# 130110-14:05:07,730 interface INFO:
# 	 stdout 2013-01-10T14:05:07.730297:49 slices processed
# 130110-14:05:07,773 interface INFO:
# 	 stdout 2013-01-10T14:05:07.773256:50 slices processed
# 130110-14:05:07,815 interface INFO:
# 	 stdout 2013-01-10T14:05:07.815944:51 slices processed
# 130110-14:05:07,858 interface INFO:
# 	 stdout 2013-01-10T14:05:07.858887:52 slices processed
# 130110-14:05:07,901 interface INFO:
# 	 stdout 2013-01-10T14:05:07.901779:53 slices processed
# 130110-14:05:07,945 interface INFO:
# 	 stdout 2013-01-10T14:05:07.945475:54 slices processed
# 130110-14:05:07,989 interface INFO:
# 	 stdout 2013-01-10T14:05:07.989396:55 slices processed
# 130110-14:05:08,33 interface INFO:
# 	 stdout 2013-01-10T14:05:08.033351:56 slices processed
# 130110-14:05:08,76 interface INFO:
# 	 stdout 2013-01-10T14:05:08.076868:57 slices processed
# 130110-14:05:08,120 interface INFO:
# 	 stdout 2013-01-10T14:05:08.119999:58 slices processed
# 130110-14:05:08,161 interface INFO:
# 	 stdout 2013-01-10T14:05:08.161846:59 slices processed
# 130110-14:05:08,203 interface INFO:
# 	 stdout 2013-01-10T14:05:08.203089:60 slices processed
# 130110-14:05:08,243 interface INFO:
# 	 stdout 2013-01-10T14:05:08.243771:61 slices processed
# 130110-14:05:08,284 interface INFO:
# 	 stdout 2013-01-10T14:05:08.284194:62 slices processed
# 130110-14:05:08,323 interface INFO:
# 	 stdout 2013-01-10T14:05:08.323826:63 slices processed
# 130110-14:05:08,362 interface INFO:
# 	 stdout 2013-01-10T14:05:08.362638:64 slices processed
# 130110-14:05:08,400 interface INFO:
# 	 stdout 2013-01-10T14:05:08.400612:65 slices processed
# 130110-14:05:08,438 interface INFO:
# 	 stdout 2013-01-10T14:05:08.438682:66 slices processed
# 130110-14:05:08,475 interface INFO:
# 	 stdout 2013-01-10T14:05:08.475560:67 slices processed
# 130110-14:05:08,511 interface INFO:
# 	 stdout 2013-01-10T14:05:08.511382:68 slices processed
# 130110-14:05:08,546 interface INFO:
# 	 stdout 2013-01-10T14:05:08.546358:69 slices processed
# 130110-14:05:08,580 interface INFO:
# 	 stdout 2013-01-10T14:05:08.580164:70 slices processed
# 130110-14:05:08,612 interface INFO:
# 	 stdout 2013-01-10T14:05:08.612192:71 slices processed
# 130110-14:05:08,643 interface INFO:
# 	 stdout 2013-01-10T14:05:08.643915:72 slices processed
# 130110-14:05:08,673 interface INFO:
# 	 stdout 2013-01-10T14:05:08.673820:73 slices processed
# 130110-14:05:08,702 interface INFO:
# 	 stdout 2013-01-10T14:05:08.702749:74 slices processed
# 130110-14:05:08,729 interface INFO:
# 	 stdout 2013-01-10T14:05:08.729761:75 slices processed
# 130110-14:05:08,756 interface INFO:
# 	 stdout 2013-01-10T14:05:08.756561:76 slices processed
# 130110-14:05:08,781 interface INFO:
# 	 stdout 2013-01-10T14:05:08.781295:77 slices processed
# 130110-14:05:08,804 interface INFO:
# 	 stdout 2013-01-10T14:05:08.804086:78 slices processed
# 130110-14:05:08,826 interface INFO:
# 	 stdout 2013-01-10T14:05:08.826298:79 slices processed
# 130110-14:05:08,846 interface INFO:
# 	 stdout 2013-01-10T14:05:08.846505:80 slices processed
# 130110-14:05:08,865 interface INFO:
# 	 stdout 2013-01-10T14:05:08.865607:81 slices processed
# 130110-14:05:08,882 interface INFO:
# 	 stdout 2013-01-10T14:05:08.882466:82 slices processed
# 130110-14:05:08,897 interface INFO:
# 	 stdout 2013-01-10T14:05:08.897449:83 slices processed
# 130110-14:05:08,910 interface INFO:
# 	 stdout 2013-01-10T14:05:08.910898:84 slices processed
# 130110-14:05:08,921 interface INFO:
# 	 stdout 2013-01-10T14:05:08.921926:85 slices processed
# 130110-14:05:08,931 interface INFO:
# 	 stdout 2013-01-10T14:05:08.931263:86 slices processed
# 130110-14:05:08,938 interface INFO:
# 	 stdout 2013-01-10T14:05:08.938604:87 slices processed
# 130110-14:05:08,943 interface INFO:
# 	 stdout 2013-01-10T14:05:08.943880:88 slices processed
# 130110-14:05:08,947 interface INFO:
# 	 stdout 2013-01-10T14:05:08.947327:89 slices processed
# 130110-14:05:08,947 interface INFO:
# 	 stdout 2013-01-10T14:05:08.947327:90 slices processed
# 130110-14:05:08,948 interface INFO:
# 	 stdout 2013-01-10T14:05:08.948206:91 slices processed
# 130110-14:05:08,948 interface INFO:
# 	 stdout 2013-01-10T14:05:08.948206:92 slices processed
# 130110-14:05:08,948 interface INFO:
# 	 stdout 2013-01-10T14:05:08.948206:93 slices processed
# 130110-14:05:08,948 interface INFO:
# 	 stdout 2013-01-10T14:05:08.948206:94 slices processed
# 130110-14:05:08,949 interface INFO:
# 	 stdout 2013-01-10T14:05:08.948206:95 slices processed
# 130110-14:05:08,949 interface INFO:
# 	 stdout 2013-01-10T14:05:08.948206:96 slices processed
# 130110-14:05:08,949 interface INFO:
# 	 stdout 2013-01-10T14:05:08.948206:97 slices processed
# 130110-14:05:08,949 interface INFO:
# 	 stdout 2013-01-10T14:05:08.948206:98 slices processed
# 130110-14:05:08,949 interface INFO:
# 	 stdout 2013-01-10T14:05:08.948206:99 slices processed
# 130110-14:05:08,950 interface INFO:
# 	 stdout 2013-01-10T14:05:08.948206:100 slices processed
# 130110-14:05:09,848 interface INFO:
# 	 stdout 2013-01-10T14:05:09.848469:4.1.9
# 130110-14:05:09,868 workflow INFO:
# 	 Executing node sinker in dir: /home/oesteban/workspace/ACWE-Reg/Data/ModelGeneration/Model1/Model_Process/sinker

# %% [markdown]
# <h2>Model restoration</h2>

# %%
est_field = nib.load('../../Release/deformed2_fieldHD.nii.gz').get_data()
est_field = est_field[:,:,:,0,:]
plt.imshow( field[30,:,:,1] - est_field[30,:,:,1] )
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x5fd1440>

# %%
import math
def get_phi( x, y ):
    if x==0 and y==0:
        return 0
    elif x>=0:
        return math.asin( y / math.sqrt( x**2 + y**2 ) )
    else:
        return -math.asin( y / math.sqrt( x**2 + y**2 ) ) + math.pi
        
vphi = np.vectorize( get_phi )

# %%
from tvtk.api import tvtk
import matplotlib.mlab as ml
import nibabel as nib

def plotSlice( sliceId, points1, points2, fa_data, extent ):
    plt.imshow( fa_data[sliceId,:,:], extent=extent, cmap=cm.gray )
    plt.xticks( [] )
    plt.yticks( [] )
    
    cont1 = points1[ points1[:,1] == sliceId ]
    o = (0.5*(fa_data.shape[0]-1),0.5*(fa_data.shape[2]-1))
    phis = vphi( cont1[:,0]-o[0], cont1[:,2]-o[1])
    res = np.take( cont1, np.argsort(phis), axis=0 )
    plt.plot( res[:,0], res[:,2], linewidth=3 )
    
    if points2==None:
        return
    
    cont2 = points2[ abs(points2[:,1] - sliceId)<0.5 ]
    phis2 = vphi( cont2[:,0]-o[0], cont2[:,2]-o[1])
    res2 = np.take( cont2, np.argsort(phis2), axis=0 )
    plt.plot( res2[:,0], res2[:,2], linewidth=3, color='r' )

# %%
fa = nib.load('Model1/deformed2_FA.nii.gz')
fa_data = fa.get_data()
fa_data = np.swapaxes( fa_data, 0, 1 )
fa_data = np.swapaxes( fa_data, 1, 2 )
extent=[0,fa_data.shape[0]-1,fa_data.shape[1]-1,0]

#mesh = tvtk.PolyDataReader( file_name= 'Model1/wm_prior.vtk' )
mesh = tvtk.PolyDataReader( file_name= '../../Release/deformed2-wm.vtk' )
mesh.output.update()
points1 = np.array( mesh.output.points )
mesh2 = tvtk.PolyDataReader( file_name= '../../Release/deformed2-csf.vtk' )
mesh2.output.update()
points2 = np.array(mesh2.output.points)

# %%
for i,sl in enumerate([ 25, 35, 45, 55, 65 ]):
    plt.figure(figsize=(15,15) )
    plotSlice( sl, points1, points2, fa_data, extent )
    plt.savefig('../../Release/fig_contours_%02d.eps' % i, dpi=300, figsize=(15,15), bbox_inches='tight', pad_inches=0 )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-d49dbfe2cfe4> in <module>()
#       1 for i,sl in enumerate([ 25, 35, 45, 55, 65 ]):
#       2     plt.figure(figsize=(15,15) )
# ----> 3     plotSlice( sl, points1, points2, fa_data, extent )
#       4     plt.savefig('../../Release/fig_contours_%02d.eps' % i, dpi=300, figsize=(15,15), bbox_inches='tight', pad_inches=0 )
#
# <ipython-input-17-7023a2255214> in plotSlice(sliceId, points1, points2, fa_data, extent)
#      10     cont1 = points1[ points1[:,1] == sliceId ]
#      11     o = (0.5*(fa_data.shape[0]-1),0.5*(fa_data.shape[2]-1))
# ---> 12     phis = vphi( cont1[:,0]-o[0], cont1[:,2]-o[1])
#      13     res = np.take( cont1, np.argsort(phis), axis=0 )
#      14     plt.plot( res[:,0], res[:,2], linewidth=3 )
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/function_base.pyc in __call__(self, *args)
#    1859             newargs = []
#    1860             for arg in args:
# -> 1861                 newargs.append(asarray(arg).flat[0])
#    1862             theout = self.thefunc(*newargs)
#    1863             if isinstance(theout, tuple):
#
# IndexError: invalid index

# %%
fa = nib.load('Model1/dtifit__FA.nii.gz')
fa_data = fa.get_data()
fa_data = np.swapaxes( fa_data, 0, 1 )
fa_data = np.swapaxes( fa_data, 1, 2 )

for i,sl in enumerate([ 25, 35, 45, 55, 65 ]):
    plt.figure(figsize=(15,15) )
    plotSlice( sl, points1, None, fa_data, extent )
    plt.savefig('fig_modelFA_%02d.eps' % i, dpi=300, figsize=(15,15), bbox_inches='tight', pad_inches=0 )

# %%
grid_points =  np.array( (x,y,z)).T
new_positions = ( grid_points + est_field ).reshape(-1,3).T
new_img = map_coordinates( fa_data, new_positions ).reshape( np.shape(fa_data) )
new_img[new_img<0.0] = 0.0
niiHS = nib.Nifti1Image( new_img.T, fa.get_affine(), fa.get_header() )
nib.save( niiHS, 'Model1/restored_FA.nii.gz' )

# %%
mesh.output.update()
points = np.array( mesh.output.points )
contour = points[ points[:,1] == sliceId ]


#zb = np.array( cont1[:,1] )
#xi = np.linspace(0, datashape[0]-1 )
#yi = np.linspace(0, datashape[1]-1 )
#zi = ml.griddata( cont1[:,0],cont1[:,2], zb, xi, yi)
#plt.contour(xi, yi, zi, levels=[sliceId], linewidths=3 )
#zb2 = np.array( points2[:,1])
#zi2 = ml.griddata( points2[:,0],points2[:,2], zb2, xi, yi)
#plt.contour(xi, yi, zi2, levels=[sliceId], colors='r', linewidths=3 )

#plt.plot( contour2[:,0], contour2[:,2], 'o', color='r', markersize=2 )
# Out:
# [ 63.  30.  27.]
