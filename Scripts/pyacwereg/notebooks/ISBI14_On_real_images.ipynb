# %%
import os
import os.path as op
import nipype.pipeline.engine as pe             # pypeline engine
import pyacwereg.workflows.epi as epi

# %%
# set up folders
subject_id = 'S400'
data_dir = op.abspath( '/home/annalisa/data' )
freesurfer_subjects_dir = op.join( data_dir, 'IXI', 'FREESURFER' )
subject_path = op.join( data_dir, 'IXI', 'subjects', subject_id )

# %%
prep = epi.smri_preparation()
prep.base_dir = op.abspath( op.join( data_dir, 'results' ) )

prep.inputs.inputnode.subject_id = subject_id
prep.inputs.inputnode.fs_subjects_dir = freesurfer_subjects_dir
prep.inputs.inputnode.in_fmap_mag = op.join( data_dir, 'DTI', 'S000', 'ts0', 'FM_mag.nii.gz' )
prep.inputs.inputnode.in_fmap_pha = op.join( data_dir, 'DTI', 'S000', 'ts0', 'FM_pha.nii.gz' )
prep.inputs.inputnode.in_t1w_brain = op.join( freesurfer_subjects_dir, subject_id, 'mri', 'brain.finalsurfs.mgz' )
prep.inputs.inputnode.in_t2w = op.join( subject_path, 'T2-Guys-0977.nii.gz' )

# %%
from IPython.display import Image
prep.write_graph()
Image( filename=op.join( prep.base_dir, prep.name, 'graph.dot.png' ) )
# Out:
# INFO:workflow:Converting dotfile: /home/annalisa/data/results/sMRI_prepare/graph.dot to png format

# %%
prep.run()
# Out:
# INFO:workflow:['check', 'execution', 'logging']
# INFO:workflow:Running in parallel.
# INFO:workflow:Submitting 4 jobs
# INFO:workflow:Executing: T2w_to_T1w ID: 0
# INFO:workflow:[Job finished] jobname: T2w_to_T1w jobid: 0
# INFO:workflow:Executing: To_Nifti_1 ID: 1
# INFO:workflow:[Job finished] jobname: To_Nifti_1 jobid: 1
# INFO:workflow:Executing: To_Nifti_3 ID: 2
# INFO:workflow:[Job finished] jobname: To_Nifti_3 jobid: 2
# INFO:workflow:Executing: To_Nifti_0 ID: 5
# INFO:workflow:[Job finished] jobname: To_Nifti_0 jobid: 5
# INFO:workflow:Submitting 4 jobs
# INFO:workflow:Executing: Bias_T1 ID: 3
# INFO:workflow:[Job finished] jobname: Bias_T1 jobid: 3
# INFO:workflow:Executing: Binarize ID: 4
# INFO:workflow:[Job finished] jobname: Binarize jobid: 4
# INFO:workflow:Executing: MaskBrain_T2w ID: 7
# INFO:workflow:[Job finished] jobname: MaskBrain_T2w jobid: 7
# INFO:workflow:Executing: GetFirst ID: 11
# INFO:workflow:[Job finished] jobname: GetFirst jobid: 11
# INFO:workflow:Submitting 3 jobs
# INFO:workflow:Executing: SegmentT1 ID: 6
# INFO:workflow:[Job finished] jobname: SegmentT1 jobid: 6
# INFO:workflow:Executing: To_Nifti_2 ID: 8
# INFO:workflow:[Job finished] jobname: To_Nifti_2 jobid: 8
# INFO:workflow:Executing: Bias ID: 12
# INFO:workflow:[Job finished] jobname: Bias jobid: 12
# INFO:workflow:Submitting 2 jobs
# INFO:workflow:Executing: JoinNames ID: 9
# INFO:workflow:[Job finished] jobname: JoinNames jobid: 9
# INFO:workflow:Executing: BrainExtraction ID: 13
# INFO:workflow:[Job finished] jobname: BrainExtraction jobid: 13
# INFO:workflow:Submitting 2 jobs
# INFO:workflow:Executing: Combine ID: 10
# INFO:workflow:[Job finished] jobname: Combine jobid: 10
# INFO:workflow:Executing: FM_to_T1 ID: 14
# INFO:workflow:[Job finished] jobname: FM_to_T1 jobid: 14
# INFO:workflow:Submitting 2 jobs
# INFO:workflow:Executing: Brain_FMap_Mag ID: 15
# INFO:workflow:[Job finished] jobname: Brain_FMap_Mag jobid: 15
# INFO:workflow:Executing: ApplyANTs ID: 17
# INFO:workflow:[Job finished] jobname: ApplyANTs jobid: 17
# INFO:workflow:Submitting 1 jobs
# INFO:workflow:Executing: OutMask ID: 16
# INFO:workflow:[Job finished] jobname: OutMask jobid: 16
# INFO:workflow:Submitting 1 jobs
# INFO:workflow:Executing: Brain_FMap_Pha ID: 18
# INFO:workflow:[Job finished] jobname: Brain_FMap_Pha jobid: 18
# INFO:workflow:Submitting 1 jobs
# INFO:workflow:Executing: SmoothPhaseMap ID: 19
# INFO:workflow:[Job finished] jobname: SmoothPhaseMap jobid: 19

# %%
dist = epi.distortion_workflow()
dist.base_dir = op.abspath( op.join( data_dir, 'results' ) )
# Out:
# /home/oesteban/workspace/nipype/nipype/interfaces/fsl/preprocess.py:1256: UserWarning: This interface has not been fully tested. Please report any failures.
#   'This interface has not been fully tested. Please report any failures.')
# /home/oesteban/workspace/nipype/nipype/interfaces/base.py:376: UserWarning: Input icorr requires inputs: shift_in_file
#   warn(msg)
# /home/oesteban/workspace/nipype/nipype/interfaces/fsl/preprocess.py:1256: UserWarning: This interface has not been fully tested. Please report any failures.
#   'This interface has not been fully tested. Please report any failures.')
# /home/oesteban/workspace/nipype/nipype/interfaces/fsl/preprocess.py:1256: UserWarning: This interface has not been fully tested. Please report any failures.
#   'This interface has not been fully tested. Please report any failures.')
# /home/oesteban/workspace/nipype/nipype/interfaces/base.py:376: UserWarning: Input icorr requires inputs: shift_in_file
#   warn(msg)
# /home/oesteban/workspace/nipype/nipype/interfaces/fsl/preprocess.py:1256: UserWarning: This interface has not been fully tested. Please report any failures.
#   'This interface has not been fully tested. Please report any failures.')

# %%
dist.inputs.inputnode.in_file = op.join( prep.base_dir, prep.name, 'Combine', 'brain.finalsurfs_out_corrected_merged.nii.gz' )
dist.inputs.inputnode.in_pha = op.join( prep.base_dir, prep.name, 'SmoothPhaseMap', 'FM_pha_out_trans_masked_filt.nii.gz' )
dist.inputs.inputnode.in_mag = op.join( prep.base_dir, prep.name, 'Brain_FMap_Mag', 'transform_Warped_masked.nii.gz' )
dist.inputs.inputnode.in_mask = op.join( prep.base_dir, prep.name, 'OutMask', 'transform_Warped_masked_thresh.nii.gz' )
dist.inputs.inputnode.in_tpms = [ op.join( prep.base_dir, prep.name, 'SegmentT1', 'brain.finalsurfs_out_corrected_pve_%d.nii.gz' ) % r for r in range(3) ]
dist.inputs.inputnode.te_incr = 2.46e-3
dist.inputs.inputnode.echospacing = 0.77e-3
dist.inputs.inputnode.encoding_direction = 'y'

# %%
dist.write_graph()
Image( filename=op.join( dist.base_dir, dist.name, 'graph.dot.png' ) )
# Out:
# INFO:workflow:Converting dotfile: /home/annalisa/data/results/synthetic_distortion/graph.dot to png format

# %%
res_dist = dist.run()
# Out:
# INFO:workflow:['check', 'execution', 'logging']
# INFO:workflow:Running in parallel.
# INFO:workflow:Submitting 2 jobs
# INFO:workflow:Executing: split_DWI ID: 0
# INFO:workflow:Executing: fsl_prepare_fieldmap ID: 1
# INFO:workflow:[Job finished] jobname: split_DWI jobid: 0
# INFO:workflow:Executing node split_DWI in dir: /home/annalisa/data/results/synthetic_distortion/Fugue_WarpDWIs/split_DWI
# INFO:workflow:Executing node fsl_prepare_fieldmap in dir: /home/annalisa/data/results/synthetic_distortion/fsl_prepare_fieldmap
# INFO:workflow:Running: fsl_prepare_fieldmap SIEMENS /home/annalisa/data/results/sMRI_prepare/SmoothPhaseMap/FM_pha_out_trans_masked_filt.nii.gz /home/annalisa/data/results/sMRI_prepare/Brain_FMap_Mag/transform_Warped_masked.nii.gz /home/annalisa/data/results/synthetic_distortion/fsl_prepare_fieldmap/FM_pha_out_trans_masked_filt_fslprepared.nii.gz 2.460000
# ERROR:workflow:['Node fsl_prepare_fieldmap failed to run on host hades.']
# INFO:workflow:Saving crash info to /home/oesteban/workspace/ACWE-Registration/Scripts/pyacwereg/notebooks/crash-20140304-174014-oesteban-fsl_prepare_fieldmap.pklz
# INFO:workflow:Traceback (most recent call last):
#   File "/home/oesteban/workspace/nipype/nipype/pipeline/plugins/multiproc.py", line 18, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/home/oesteban/workspace/nipype/nipype/pipeline/engine.py", line 1390, in run
#     self._run_interface()
#   File "/home/oesteban/workspace/nipype/nipype/pipeline/engine.py", line 1500, in _run_interface
#     self._result = self._run_command(execute)
#   File "/home/oesteban/workspace/nipype/nipype/pipeline/engine.py", line 1626, in _run_command
#     result = self._interface.run()
#   File "/home/oesteban/workspace/nipype/nipype/interfaces/base.py", line 946, in run
#     runtime = self._run_interface(runtime)
#   File "/home/oesteban/workspace/nipype/nipype/interfaces/fsl/epi.py", line 97, in _run_interface
#     im = nib.load( out_file )
#   File "/usr/lib/pymodules/python2.7/nibabel/loadsave.py", line 54, in load
#     return klass.from_filename(filename)
#   File "/usr/lib/pymodules/python2.7/nibabel/spatialimages.py", line 411, in from_filename
#     return klass.from_file_map(file_map)
#   File "/usr/lib/pymodules/python2.7/nibabel/analyze.py", line 869, in from_file_map
#     hdrf = hdr_fh.get_prepare_fileobj(mode='rb')
#   File "/usr/lib/pymodules/python2.7/nibabel/fileholders.py", line 69, in get_prepare_fileobj
#     obj = allopen(self.filename, *args, **kwargs)
#   File "/usr/lib/pymodules/python2.7/nibabel/volumeutils.py", line 1284, in allopen
#     return opener(fname, *args, **kwargs)
#   File "/usr/lib/python2.7/gzip.py", line 34, in open
#     return GzipFile(filename, mode, compresslevel)
#   File "/usr/lib/python2.7/gzip.py", line 89, in __init__
#     fileobj = self.myfileobj = __builtin__.open(filename, mode or 'rb')
# IOError: [Errno 2] No such file or directory: '/home/annalisa/data/results/synthetic_distortion/fsl_prepare_fieldmap/FM_pha_out_trans_masked_filt_fslprepared.nii.gz'
# INFO:workflow:***********************************
# ERROR:workflow:could not run node: synthetic_distortion.fsl_prepare_fieldmap
# INFO:workflow:crashfile: /home/oesteban/workspace/ACWE-Registration/Scripts/pyacwereg/notebooks/crash-20140304-174014-oesteban-fsl_prepare_fieldmap.pklz
# INFO:workflow:***********************************
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-f5ebb23ce4e4> in <module>()
# ----> 1 res_dist = dist.run()
#
# /home/oesteban/workspace/nipype/nipype/pipeline/engine.pyc in run(self, plugin, plugin_args, updatehash)
#     691         if str2bool(self.config['execution']['create_report']):
#     692             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 693         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     694         datestr = datetime.utcnow().strftime('%Y%m%dT%H%M%S')
#     695         if str2bool(self.config['execution']['write_provenance']):
#
# /home/oesteban/workspace/nipype/nipype/pipeline/plugins/base.pyc in run(self, graph, config, updatehash)
#     262             sleep(2)
#     263         self._remove_node_dirs()
# --> 264         report_nodes_not_run(notrun)
#     265
#     266     def _get_result(self, taskid):
#
# /home/oesteban/workspace/nipype/nipype/pipeline/plugins/base.pyc in report_nodes_not_run(notrun)
#      90                 logger.debug(subnode._id)
#      91         logger.info("***********************************")
# ---> 92         raise RuntimeError(('Workflow did not execute cleanly. '
#      93                             'Check log for details'))
#      94
#
# RuntimeError: Workflow did not execute cleanly. Check log for details
